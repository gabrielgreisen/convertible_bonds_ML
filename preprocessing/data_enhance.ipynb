# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/vanilla_convertibles_data.csv")

df

# %%
from feature_engineering import engineer_features

df = engineer_features(df, [1,2,3])
df

# %%
df.to_csv("../data/vanilla_convertibles_data_enhanced.csv", index=False)

# %%
df[["price_normalized", "price_convertible"]].describe()
# Out:
#        price_normalized  price_convertible
# count    1000000.000000     1000000.000000
# mean           6.874323        1405.589251
# std            0.966492        1083.595955
# min            2.879555          16.806345
# 25%            6.256866         520.581986
# 50%            7.021000        1118.906437
# 75%            7.638385        2075.388336
# max            8.518925        5007.668733
