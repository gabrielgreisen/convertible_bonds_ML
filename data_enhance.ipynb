# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("vanilla_convertibles_data.csv")

df
# Out:
#                  S         r         q    bs_vol  credit_spread  redemption  \
# 0        60.206715  0.071022  0.039404  0.735012       0.058539         100
# 1       105.023875  0.027703  0.036579  0.636728       0.088371         100
# 2       457.758451  0.085757  0.050711  0.296074       0.080561         100
# 3       356.330783  0.050178  0.010127  0.695026       0.063523         100
# 4       450.285185  0.059966  0.028056  0.191209       0.072044         100
# ...            ...       ...       ...       ...            ...         ...
# 999995  417.797364  0.049576  0.021612  0.279284       0.138901         100
# 999996  146.413910  0.075163  0.042408  0.683901       0.079158         100
# 999997  372.745652  0.013845  0.025190  0.277562       0.009923         100
# 999998  450.607011  0.076910  0.039229  0.512960       0.057273         100
# 999999  396.652325  0.078552  0.037606  0.198678       0.010223         100
#
# ...

# %%
from feature_engineering import engineer_features

df = engineer_features(df, [1,2,3])
df
# Out:
#                  S         r         q    bs_vol  credit_spread  redemption  \
# 0        60.206715  0.071022  0.039404  0.735012       0.058539         100
# 1       105.023875  0.027703  0.036579  0.636728       0.088371         100
# 2       457.758451  0.085757  0.050711  0.296074       0.080561         100
# 3       356.330783  0.050178  0.010127  0.695026       0.063523         100
# 4       450.285185  0.059966  0.028056  0.191209       0.072044         100
# ...            ...       ...       ...       ...            ...         ...
# 999995  417.797364  0.049576  0.021612  0.279284       0.138901         100
# 999996  146.413910  0.075163  0.042408  0.683901       0.079158         100
# 999997  372.745652  0.013845  0.025190  0.277562       0.009923         100
# 999998  450.607011  0.076910  0.039229  0.512960       0.057273         100
# 999999  396.652325  0.078552  0.037606  0.198678       0.010223         100
#
# ...

# %%
df.to_csv("vanilla_convertibles_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.to_csv("vanilla_convertibles_data.csv", index=False)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

X = df.drop(columns=["price_convertible"])
y = df["price_convertible"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=67)

# %%
rf = RandomForestRegressor(n_estimators=300, max_depth=None, min_samples_split=2, min_samples_leaf=1, random_state=67)

# GridSearch for best random forest parameters
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [None, 10, 20 ,30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2", None]
}

grid_search = GridSearchCV(
    estimator = rf,
    param_grid = param_grid,
    cv = 5,
    scoring="neg_root_mean_squared_error"
)

grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best CV RMSE:", -grid_search.best_score_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 19
#       4 param_grid = {
#       5     "n_estimators": [100, 200, 300],
#       6     "max_depth": [None, 10, 20 ,30],
#    (...)
#       9     "max_features": ["sqrt", "log2", None]
#      10 }
#      12 grid_search = GridSearchCV(
#      13     estimator = rf,
#      14     param_grid = param_grid,
#      15     cv = 5,
#      16     scoring="neg_root_mean_squared_error"
#      17 )
# ---> 19 grid_search.fit(X_train, y_train)
#      21 print("Best parameters:", grid_search.best_params_)
#      22 print("Best CV RMSE:", -grid_search.best_score_)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
# ...

# %%
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# Evaluation
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 rf = RandomForestRegressor(n_estimators=300, max_depth=None, min_samples_split=2, min_samples_leaf=1, random_state=67)
# ----> 3 rf.fit(X_train, y_train)
#       5 y_pred = rf.predict(X_test)
#       7 # Evaluation
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
# ...

# %%
# Current mettrics to evaluate model characterisitcs
print("RF RMSE:", rmse)
print("RF MAE:", mae)
print("RF R^2:", r2)

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(random_state=67)

param_grid_gbr = {
    "n_estimators": [100, 200, 300],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [2, 3, 4],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "subsample": [0.8, 1.0],
    "max_features": [None, "sqrt", "log2"]
}

grid_search_gbr = GridSearchCV(
    estimator = gbr,
    param_grid = param_grid_gbr,
    cv=5,
    scoring="neg_root_mean_squared_error",
)

grid_search_gbr.fit(X_train, y_train)

print("Best GBR parameters:", grid_search_gbr.best_params_)
print("Best GBR CV RMSE:", -grid_search_gbr.best_score_)

# %%
best_gbr = grid_search_gbr.best_estimator_
best_gbr.fit(X_train, y_train)

y_pred_gbr = best_gbr.predict(X_test)

rmse_gbr = np.sqrt(mean_squared_error(y_test, y_pred_gbr))
mae_gbr = mean_absolute_error(y_test, y_pred_gbr)
r2_gbr = r2_score(y_test, y_pred_gbr)

print("Gradient Boosting Test RMSE:", rmse_gbr)
print("Gradient Boosting Test MAE:", mae_gbr)
print("Gradient Boosting Test R^2:", r2_gbr)
